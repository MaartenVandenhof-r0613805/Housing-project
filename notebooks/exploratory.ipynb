# %%
import pandas as pd

# %%
df= pd.read_excel("../outputs/Merged_output.xlsx")
df.head()
# Out:
#    Unnamed: 0     site    itemtype    rent monthly_fee postalcode    city  \
# 0           0  ImmoWeb  Huistehuur  1.100€         NaN       3000  Leuven
# 1           1  ImmoWeb  Huistehuur  1.150€         NaN       3000  Leuven
# 2           2  ImmoWeb  Huistehuur  1.200€         NaN       3000  Leuven
# 3           3  ImmoWeb  Huistehuur    850€         NaN       3000  Leuven
# 4           4  ImmoWeb  Huistehuur  1.100€         NaN       3000  Leuven
#
#         street house_number bus_number bathrooms bedrooms surface  \
# 0  Op aanvraag         None       None         1        2   129m²
# 1  Op aanvraag         None       None         1        3    85m²
# 2  Op aanvraag         None       None         1        2   120m²
# 3  Op aanvraag         None       None         1        2    62m²
# 4  Op aanvraag         None       None         1        3    99m²
#
#             epc_class                                               link
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    122 non-null    int64
#  1   site          122 non-null    object
#  2   itemtype      122 non-null    object
#  3   rent          122 non-null    object
#  4   monthly_fee   100 non-null    object
#  5   postalcode    122 non-null    object
#  6   city          122 non-null    object
#  7   street        122 non-null    object
#  8   house_number  122 non-null    object
#  9   bus_number    120 non-null    object
#  10  bathrooms     122 non-null    object
#  11  bedrooms      122 non-null    object
#  12  surface       119 non-null    object
#  13  epc_class     121 non-null    object
#  14  link          122 non-null    object
# dtypes: int64(1), object(14)
# memory usage: 14.4+ KB
